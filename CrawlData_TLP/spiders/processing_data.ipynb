# %%
import json
import pandas as pd
import re

# %%
with open('TLP.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         0.0
# 1142       79222                               vivo V30E SE         0.0
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         0.0
# 1145       24091                                 Bphone B60         0.0
#
#       special_price manufacturer operating_system              os_version  \
# 0        22490000.0        Apple              iOS                  iOS 18
# 1               0.0       Xiaomi              N/A                     N/A
# 2        26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3               0.0        Apple              iOS                  iOS 18
# 4               0.0        Apple              iOS                  iOS 18
# ...             ...          ...              ...                     ...
# 1141            0.0         Vivo          Android              Android 14
# 1142            0.0         Vivo              N/A                     N/A
# 1143            0.0       Realme          Android              Android 14
# 1144            0.0       Xiaomi              N/A                     N/A
# 1145            0.0           HP              N/A           Đang cập nhật
#
#             battery                        chipset display_size  ...  \
# 0         4.300 mAh                      Apple A18   6.1 inches  ...
# 1          5000 mAh  MediaTek Dimensity 8300-Ultra  6.67 inches  ...
# 2          5,000mAh  Snapdragon 8 Gen 3 For Galaxy   6.8 inches  ...
# 3               N/A                  Apple A18 Pro   6.3 inches  ...
# 4               N/A                  Apple A18 Pro   6.9 inches  ...
# ...             ...                            ...          ...  ...
# 1141       5500 mAh             Snapdragon 8 Gen 3  6.78 inches  ...
# 1142      5.000 mAh                            N/A          N/A  ...
# 1143       5000 mAh      MediaTek Helio G85 8 nhân  6.67 inches  ...
# 1144            N/A                            N/A          N/A  ...
# 1145  Đang cập nhật          Snapdragon 660 8 nhân          N/A  ...
#
#      product_weight mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0          170 gram                N/A        5G      USB Type-C
# 1              195g                N/A        5G             N/A
# 2              232g              120Hz        5G      USB Type-C
# 3          199 gram                N/A        5G      USB Type-C
# 4          227 gram                N/A        5G      USB Type-C
# ...             ...                ...       ...             ...
# 1141          229 g                N/A       N/A      USB Type-C
# 1142            N/A              120Hz       N/A             N/A
# 1143          185 g                N/A        4G      USB Type-C
# 1144            N/A                N/A       N/A             N/A
# 1145  Đang cập nhật                N/A       N/A             N/A
#
#               mobile_cam_bien_van_tay  \
# 0                                 N/A
# 1                                 N/A
# 2     Cảm biến vân tay trong màn hình
# 3                                 N/A
# 4                                 N/A
# ...                               ...
# 1141                              N/A
# 1142                              N/A
# 1143        Cảm biến vân tay cạnh bên
# 1144                              N/A
# 1145                              N/A
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...           0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...           0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            0.0                                                N/A
# 1143            0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            0.0                                                N/A
# 1145            5.0                                                N/A
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                N/A
# 1142                                                N/A
# 1143                                                N/A
# 1144                                                N/A
# 1145                                                N/A
#
# [1146 rows x 27 columns]

# %%
# Thay thế dữ liệu trống và dữ liệu N/A bằng giá trị 0
df = df.replace('N/A', 0)
df = df.fillna(0)
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         0.0
# 1142       79222                               vivo V30E SE         0.0
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         0.0
# 1145       24091                                 Bphone B60         0.0
#
#       special_price manufacturer operating_system              os_version  \
# 0        22490000.0        Apple              iOS                  iOS 18
# 1               0.0       Xiaomi                0                       0
# 2        26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3               0.0        Apple              iOS                  iOS 18
# 4               0.0        Apple              iOS                  iOS 18
# ...             ...          ...              ...                     ...
# 1141            0.0         Vivo          Android              Android 14
# 1142            0.0         Vivo                0                       0
# 1143            0.0       Realme          Android              Android 14
# 1144            0.0       Xiaomi                0                       0
# 1145            0.0           HP                0           Đang cập nhật
#
#             battery                        chipset display_size  ...  \
# 0         4.300 mAh                      Apple A18   6.1 inches  ...
# 1          5000 mAh  MediaTek Dimensity 8300-Ultra  6.67 inches  ...
# 2          5,000mAh  Snapdragon 8 Gen 3 For Galaxy   6.8 inches  ...
# 3                 0                  Apple A18 Pro   6.3 inches  ...
# 4                 0                  Apple A18 Pro   6.9 inches  ...
# ...             ...                            ...          ...  ...
# 1141       5500 mAh             Snapdragon 8 Gen 3  6.78 inches  ...
# 1142      5.000 mAh                              0            0  ...
# 1143       5000 mAh      MediaTek Helio G85 8 nhân  6.67 inches  ...
# 1144              0                              0            0  ...
# 1145  Đang cập nhật          Snapdragon 660 8 nhân            0  ...
#
#      product_weight mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0          170 gram                  0        5G      USB Type-C
# 1              195g                  0        5G               0
# 2              232g              120Hz        5G      USB Type-C
# 3          199 gram                  0        5G      USB Type-C
# 4          227 gram                  0        5G      USB Type-C
# ...             ...                ...       ...             ...
# 1141          229 g                  0         0      USB Type-C
# 1142              0              120Hz         0               0
# 1143          185 g                  0        4G      USB Type-C
# 1144              0                  0         0               0
# 1145  Đang cập nhật                  0         0               0
#
#               mobile_cam_bien_van_tay  \
# 0                                   0
# 1                                   0
# 2     Cảm biến vân tay trong màn hình
# 3                                   0
# 4                                   0
# ...                               ...
# 1141                                0
# 1142                                0
# 1143        Cảm biến vân tay cạnh bên
# 1144                                0
# 1145                                0
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...           0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...           0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            0.0                                                  0
# 1143            0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            0.0                                                  0
# 1145            5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
df['price'] = df['price'].apply(lambda x: 'N/A' if x == 0 else x)
df['special_price'] = df['special_price'].apply(lambda x: 'N/A' if x == 0 else x)

# %%
print(df['price'].dtype)
print(df['special_price'].dtype)
# Out:
# object
# object

# %%
# battery
df['battery'] = df['battery'].apply(lambda x: x if 'mAh' in str(x) else 0)
# Lọc dữ liệu cột battery, chỉ lấy đoạn dữ liệu trước chữ 'mAh' sau đó mới phân tích
df['battery'] = df['battery'].apply(lambda x: x.split('mAh')[0] if isinstance(x, str) else x)
def clean_battery(battery):
    if pd.isna(battery):
        return 0
    # Loại bỏ đơn vị mAh
    battery = re.sub(r'[^\d,]', '', str(battery))
    # Chuyển đổi giá trị từ dạng 5,232 thành 5232
    battery = battery.replace(',', '')

    battery = battery.replace('.', '')
    return int(battery) if battery else 0

df['battery'] = df['battery'].apply(clean_battery)
df['battery'] = df['battery'].astype(int)
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price manufacturer operating_system              os_version  \
# 0       22490000.0        Apple              iOS                  iOS 18
# 1              N/A       Xiaomi                0                       0
# 2       26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3              N/A        Apple              iOS                  iOS 18
# 4              N/A        Apple              iOS                  iOS 18
# ...            ...          ...              ...                     ...
# 1141           N/A         Vivo          Android              Android 14
# 1142           N/A         Vivo                0                       0
# 1143           N/A       Realme          Android              Android 14
# 1144           N/A       Xiaomi                0                       0
# 1145           N/A           HP                0           Đang cập nhật
#
#       battery                        chipset display_size  ... product_weight  \
# 0           0                      Apple A18   6.1 inches  ...       170 gram
# 1           0  MediaTek Dimensity 8300-Ultra  6.67 inches  ...           195g
# 2           0  Snapdragon 8 Gen 3 For Galaxy   6.8 inches  ...           232g
# 3           0                  Apple A18 Pro   6.3 inches  ...       199 gram
# 4           0                  Apple A18 Pro   6.9 inches  ...       227 gram
# ...       ...                            ...          ...  ...            ...
# 1141        0             Snapdragon 8 Gen 3  6.78 inches  ...          229 g
# 1142        0                              0            0  ...              0
# 1143        0      MediaTek Helio G85 8 nhân  6.67 inches  ...          185 g
# 1144        0                              0            0  ...              0
# 1145        0          Snapdragon 660 8 nhân            0  ...  Đang cập nhật
#
#      mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0                     0        5G      USB Type-C
# 1                     0        5G               0
# 2                 120Hz        5G      USB Type-C
# 3                     0        5G      USB Type-C
# 4                     0        5G      USB Type-C
# ...                 ...       ...             ...
# 1141                  0         0      USB Type-C
# 1142              120Hz         0               0
# 1143                  0        4G      USB Type-C
# 1144                  0         0               0
# 1145                  0         0               0
#
#               mobile_cam_bien_van_tay  \
# 0                                   0
# 1                                   0
# 2     Cảm biến vân tay trong màn hình
# 3                                   0
# 4                                   0
# ...                               ...
# 1141                                0
# 1142                                0
# 1143        Cảm biến vân tay cạnh bên
# 1144                                0
# 1145                                0
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...           0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...           0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            0.0                                                  0
# 1143            0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            0.0                                                  0
# 1145            5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
print(df['battery'].dtype)
# Out:
# int64

# %%
# chipset
df['chipset'] = df['chipset'].apply(lambda x: x.split(',')[0] if isinstance(x, str) else x)
df['chipset'] = df['chipset'].apply(lambda x: re.sub(r'\s*\d+nm|\s*tiến trình nm|\s*\(.*?\)', '', str(x), flags=re.IGNORECASE))
df['chipset'] = df['chipset'].replace('Đang cập nhật', 0)
df['chipset'] = df['chipset'].apply(lambda x: x.replace('thế hệ', 'Gen') if isinstance(x, str) else x)
df['chipset'] = df['chipset'].apply(lambda x: re.sub(r'[^\w\s]', '', x) if isinstance(x, str) else x)
df['chipset'] = df['chipset'].astype(object)
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price manufacturer operating_system              os_version  \
# 0       22490000.0        Apple              iOS                  iOS 18
# 1              N/A       Xiaomi                0                       0
# 2       26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3              N/A        Apple              iOS                  iOS 18
# 4              N/A        Apple              iOS                  iOS 18
# ...            ...          ...              ...                     ...
# 1141           N/A         Vivo          Android              Android 14
# 1142           N/A         Vivo                0                       0
# 1143           N/A       Realme          Android              Android 14
# 1144           N/A       Xiaomi                0                       0
# 1145           N/A           HP                0           Đang cập nhật
#
#       battery                        chipset display_size  ... product_weight  \
# 0           0                      Apple A18   6.1 inches  ...       170 gram
# 1           0   MediaTek Dimensity 8300Ultra  6.67 inches  ...           195g
# 2           0  Snapdragon 8 Gen 3 For Galaxy   6.8 inches  ...           232g
# 3           0                  Apple A18 Pro   6.3 inches  ...       199 gram
# 4           0                  Apple A18 Pro   6.9 inches  ...       227 gram
# ...       ...                            ...          ...  ...            ...
# 1141        0             Snapdragon 8 Gen 3  6.78 inches  ...          229 g
# 1142        0                              0            0  ...              0
# 1143        0      MediaTek Helio G85 8 nhân  6.67 inches  ...          185 g
# 1144        0                              0            0  ...              0
# 1145        0          Snapdragon 660 8 nhân            0  ...  Đang cập nhật
#
#      mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0                     0        5G      USB Type-C
# 1                     0        5G               0
# 2                 120Hz        5G      USB Type-C
# 3                     0        5G      USB Type-C
# 4                     0        5G      USB Type-C
# ...                 ...       ...             ...
# 1141                  0         0      USB Type-C
# 1142              120Hz         0               0
# 1143                  0        4G      USB Type-C
# 1144                  0         0               0
# 1145                  0         0               0
#
#               mobile_cam_bien_van_tay  \
# 0                                   0
# 1                                   0
# 2     Cảm biến vân tay trong màn hình
# 3                                   0
# 4                                   0
# ...                               ...
# 1141                                0
# 1142                                0
# 1143        Cảm biến vân tay cạnh bên
# 1144                                0
# 1145                                0
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...           0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...           0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            0.0                                                  0
# 1143            0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            0.0                                                  0
# 1145            5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
# display_size
df['display_size'] = df['display_size'].apply(lambda x: re.sub(r'[^\d.]', '', x) if x else '0').replace('', '0').astype(float)
df

df['display_size'] = df['display_size'].astype(float)

# %%
print(df['display_size'].dtype)
# Out:
# float64

# %%
# display_resolution
df['display_resolution'] = df['display_resolution'].apply(lambda x: re.sub(r'\s*\(.*?\)|[^\d×x]', '', x) if isinstance(x, str) else x)
df['display_resolution'] = df['display_resolution'].apply(lambda x: x[:-1] if isinstance(x, str) and x.endswith('x') else x)
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price manufacturer operating_system              os_version  \
# 0       22490000.0        Apple              iOS                  iOS 18
# 1              N/A       Xiaomi                0                       0
# 2       26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3              N/A        Apple              iOS                  iOS 18
# 4              N/A        Apple              iOS                  iOS 18
# ...            ...          ...              ...                     ...
# 1141           N/A         Vivo          Android              Android 14
# 1142           N/A         Vivo                0                       0
# 1143           N/A       Realme          Android              Android 14
# 1144           N/A       Xiaomi                0                       0
# 1145           N/A           HP                0           Đang cập nhật
#
#       battery                        chipset  display_size  ...  \
# 0           0                      Apple A18          6.10  ...
# 1           0   MediaTek Dimensity 8300Ultra          6.67  ...
# 2           0  Snapdragon 8 Gen 3 For Galaxy          6.80  ...
# 3           0                  Apple A18 Pro          6.30  ...
# 4           0                  Apple A18 Pro          6.90  ...
# ...       ...                            ...           ...  ...
# 1141        0             Snapdragon 8 Gen 3          6.78  ...
# 1142        0                              0          0.00  ...
# 1143        0      MediaTek Helio G85 8 nhân          6.67  ...
# 1144        0                              0          0.00  ...
# 1145        0          Snapdragon 660 8 nhân          0.00  ...
#
#      product_weight mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0          170 gram                  0        5G      USB Type-C
# 1              195g                  0        5G               0
# 2              232g              120Hz        5G      USB Type-C
# 3          199 gram                  0        5G      USB Type-C
# 4          227 gram                  0        5G      USB Type-C
# ...             ...                ...       ...             ...
# 1141          229 g                  0         0      USB Type-C
# 1142              0              120Hz         0               0
# 1143          185 g                  0        4G      USB Type-C
# 1144              0                  0         0               0
# 1145  Đang cập nhật                  0         0               0
#
#               mobile_cam_bien_van_tay  \
# 0                                   0
# 1                                   0
# 2     Cảm biến vân tay trong màn hình
# 3                                   0
# 4                                   0
# ...                               ...
# 1141                                0
# 1142                                0
# 1143        Cảm biến vân tay cạnh bên
# 1144                                0
# 1145                                0
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...           0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...           0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...           0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            0.0                                                  0
# 1143            0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            0.0                                                  0
# 1145            5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
# memory_internal
df['memory_internal'] = df['memory_internal'].apply(lambda x: int(re.sub(r'[^\d]', '', x.split('+')[0])) if isinstance(x, str) and re.sub(r'[^\d]', '', x.split('+')[0]) else 0)
df['memory_internal'] = df['memory_internal'].astype(int)

# %%
print(df['memory_internal'].dtype)
# Out:
# int64

# %%
# storage
df['storage'] = df['storage'].apply(lambda x: int(re.sub(r'[^\d]', '', x)) if isinstance(x, str) and re.sub(r'[^\d]', '', x) else 0)
df['storage'] = df['storage'].astype(int)

# %%
print(df['storage'].dtype)
# Out:
# int64

# %%
# product_weight
df['product_weight'] = df['product_weight'].apply(lambda x: re.sub(r'[^\d]', '', x.split('g')[0]) if isinstance(x, str) else x)
df['product_weight'] = df['product_weight'].apply(lambda x: int(x) if x else 0)
# Chuyển đổi các giá trị lớn hơn 1000 về giá trị thập phân và ép kiểu float
df['product_weight'] = df['product_weight'].apply(lambda x: x / 10 if x > 1000 else x).astype(float)
df
# Out:
#       product_id                                       name       price  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price manufacturer operating_system              os_version  \
# 0       22490000.0        Apple              iOS                  iOS 18
# 1              N/A       Xiaomi                0                       0
# 2       26990000.0      Samsung          Android  Android 14, One UI 6.1
# 3              N/A        Apple              iOS                  iOS 18
# 4              N/A        Apple              iOS                  iOS 18
# ...            ...          ...              ...                     ...
# 1141           N/A         Vivo          Android              Android 14
# 1142           N/A         Vivo                0                       0
# 1143           N/A       Realme          Android              Android 14
# 1144           N/A       Xiaomi                0                       0
# 1145           N/A           HP                0           Đang cập nhật
#
#       battery                        chipset  display_size  ...  \
# 0           0                      Apple A18          6.10  ...
# 1           0   MediaTek Dimensity 8300Ultra          6.67  ...
# 2           0  Snapdragon 8 Gen 3 For Galaxy          6.80  ...
# 3           0                  Apple A18 Pro          6.30  ...
# 4           0                  Apple A18 Pro          6.90  ...
# ...       ...                            ...           ...  ...
# 1141        0             Snapdragon 8 Gen 3          6.78  ...
# 1142        0                              0          0.00  ...
# 1143        0      MediaTek Helio G85 8 nhân          6.67  ...
# 1144        0                              0          0.00  ...
# 1145        0          Snapdragon 660 8 nhân          0.00  ...
#
#      product_weight mobile_tan_so_quet loai_mang mobile_cong_sac  \
# 0             170.0                  0        5G      USB Type-C
# 1             195.0                  0        5G               0
# 2             232.0              120Hz        5G      USB Type-C
# 3             199.0                  0        5G      USB Type-C
# 4             227.0                  0        5G      USB Type-C
# ...             ...                ...       ...             ...
# 1141          229.0                  0         0      USB Type-C
# 1142            0.0              120Hz         0               0
# 1143          185.0                  0        4G      USB Type-C
# 1144            0.0                  0         0               0
# 1145            0.0                  0         0               0
#
#               mobile_cam_bien_van_tay  \
# 0                                   0
# 1                                   0
# 2     Cảm biến vân tay trong màn hình
# 3                                   0
# 4                                   0
# ...                               ...
# 1141                                0
# 1142                                0
# 1143        Cảm biến vân tay cạnh bên
# 1144                                0
# 1145                                0
#
#                                    warranty_information  total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...            0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...            0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...           22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...            3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           13
# ...                                                 ...          ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...            0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...            2
#
#       average_rating                                 key_selling_points  \
# 0                0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1                0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2                4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3                5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4                4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...              ...                                                ...
# 1141             0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142             0.0                                                  0
# 1143             0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144             0.0                                                  0
# 1145             5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
print(df['product_weight'].dtype)
# Out:
# float64

# %%
# mobile_tan_so_quet
df['mobile_tan_so_quet'] = df['mobile_tan_so_quet'].apply(lambda x: int(re.sub(r'[^\d]', '', x)) if isinstance(x, str) and re.sub(r'[^\d]', '', x) else 0)

# %%
print(df['mobile_tan_so_quet'].dtype)
# Out:
# int64

# %%
# total_count
df['total_count'] = df['total_count'].astype(int)

# %%
print(df['total_count'].dtype)
# Out:
# int64

# %%
# average_rating
df['average_rating'] = df['average_rating'].astype(float)

# %%
print(df['average_rating'].dtype)
# Out:
# float64

# %%
# Đổi tên các cột
df.rename(columns={
    'price': 'price (VND)',
    'special_price': 'special_price (VND)',
    'battery': 'battery (mAh)',
    'display_size': 'display_size (inch)',
    'display_resolution': 'display_resolution (px)',
    'memory_internal': 'memory_internal (GB)',
    'storage': 'storage (GB)',
    'product_weight': 'product_weight (g)',
}, inplace=True)

df
# Out:
#       product_id                                       name price (VND)  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price (VND) manufacturer operating_system  \
# 0             22490000.0        Apple              iOS
# 1                    N/A       Xiaomi                0
# 2             26990000.0      Samsung          Android
# 3                    N/A        Apple              iOS
# 4                    N/A        Apple              iOS
# ...                  ...          ...              ...
# 1141                 N/A         Vivo          Android
# 1142                 N/A         Vivo                0
# 1143                 N/A       Realme          Android
# 1144                 N/A       Xiaomi                0
# 1145                 N/A           HP                0
#
#                   os_version  battery (mAh)                        chipset  \
# 0                     iOS 18              0                      Apple A18
# 1                          0              0   MediaTek Dimensity 8300Ultra
# 2     Android 14, One UI 6.1              0  Snapdragon 8 Gen 3 For Galaxy
# 3                     iOS 18              0                  Apple A18 Pro
# 4                     iOS 18              0                  Apple A18 Pro
# ...                      ...            ...                            ...
# 1141              Android 14              0             Snapdragon 8 Gen 3
# 1142                       0              0                              0
# 1143              Android 14              0      MediaTek Helio G85 8 nhân
# 1144                       0              0                              0
# 1145           Đang cập nhật              0          Snapdragon 660 8 nhân
#
#       display_size (inch)  ... product_weight (g) mobile_tan_so_quet  \
# 0                    6.10  ...              170.0                  0
# 1                    6.67  ...              195.0                  0
# 2                    6.80  ...              232.0                120
# 3                    6.30  ...              199.0                  0
# 4                    6.90  ...              227.0                  0
# ...                   ...  ...                ...                ...
# 1141                 6.78  ...              229.0                  0
# 1142                 0.00  ...                0.0                120
# 1143                 6.67  ...              185.0                  0
# 1144                 0.00  ...                0.0                  0
# 1145                 0.00  ...                0.0                  0
#
#      loai_mang mobile_cong_sac          mobile_cam_bien_van_tay  \
# 0           5G      USB Type-C                                0
# 1           5G               0                                0
# 2           5G      USB Type-C  Cảm biến vân tay trong màn hình
# 3           5G      USB Type-C                                0
# 4           5G      USB Type-C                                0
# ...        ...             ...                              ...
# 1141         0      USB Type-C                                0
# 1142         0               0                                0
# 1143        4G      USB Type-C        Cảm biến vân tay cạnh bên
# 1144         0               0                                0
# 1145         0               0                                0
#
#                                    warranty_information  total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...            0
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...            0
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...           22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...            3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           13
# ...                                                 ...          ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...            0
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...            0
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...            2
#
#       average_rating                                 key_selling_points  \
# 0                0.0  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1                0.0  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2                4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3                5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4                4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...              ...                                                ...
# 1141             0.0  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142             0.0                                                  0
# 1143             0.0  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144             0.0                                                  0
# 1145             5.0                                                  0
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                  0
# 1142                                                  0
# 1143                                                  0
# 1144                                                  0
# 1145                                                  0
#
# [1146 rows x 27 columns]

# %%
# Chuyển toàn bộ dữ liệu 0 thành N/A
df['chipset'] = df['chipset'].replace([0, '0'], 'N/A')
df = df.replace(0, 'N/A')
df = df.replace('Đang cập nhật', 'N/A')
df
# Out:
#       product_id                                       name price (VND)  \
# 0          59254          iPhone 16 128GB | Chính hãng VN/A  22990000.0
# 1          76439                                 Xiaomi 14T  13990000.0
# 2          59294        Samsung Galaxy S24 Ultra 12GB 256GB  33990000.0
# 3          59257      iPhone 16 Pro 128GB | Chính hãng VN/A  28990000.0
# 4          59258  iPhone 16 Pro Max 256GB | Chính hãng VN/A  34990000.0
# ...          ...                                        ...         ...
# 1141       84377                            vivo X100 Ultra         N/A
# 1142       79222                               vivo V30E SE         N/A
# 1143       87306                       realme C65 8GB 128GB   4430000.0
# 1144       91991              Xiaomi Redmi Note 14 Pro Plus         N/A
# 1145       24091                                 Bphone B60         N/A
#
#      special_price (VND) manufacturer operating_system  \
# 0             22490000.0        Apple              iOS
# 1                    N/A       Xiaomi              N/A
# 2             26990000.0      Samsung          Android
# 3                    N/A        Apple              iOS
# 4                    N/A        Apple              iOS
# ...                  ...          ...              ...
# 1141                 N/A         Vivo          Android
# 1142                 N/A         Vivo              N/A
# 1143                 N/A       Realme          Android
# 1144                 N/A       Xiaomi              N/A
# 1145                 N/A           HP              N/A
#
#                   os_version battery (mAh)                        chipset  \
# 0                     iOS 18           N/A                      Apple A18
# 1                        N/A           N/A   MediaTek Dimensity 8300Ultra
# 2     Android 14, One UI 6.1           N/A  Snapdragon 8 Gen 3 For Galaxy
# 3                     iOS 18           N/A                  Apple A18 Pro
# 4                     iOS 18           N/A                  Apple A18 Pro
# ...                      ...           ...                            ...
# 1141              Android 14           N/A             Snapdragon 8 Gen 3
# 1142                     N/A           N/A                            N/A
# 1143              Android 14           N/A      MediaTek Helio G85 8 nhân
# 1144                     N/A           N/A                            N/A
# 1145                     N/A           N/A          Snapdragon 660 8 nhân
#
#      display_size (inch)  ... product_weight (g) mobile_tan_so_quet loai_mang  \
# 0                    6.1  ...              170.0                N/A        5G
# 1                   6.67  ...              195.0                N/A        5G
# 2                    6.8  ...              232.0                120        5G
# 3                    6.3  ...              199.0                N/A        5G
# 4                    6.9  ...              227.0                N/A        5G
# ...                  ...  ...                ...                ...       ...
# 1141                6.78  ...              229.0                N/A       N/A
# 1142                 N/A  ...                N/A                120       N/A
# 1143                6.67  ...              185.0                N/A        4G
# 1144                 N/A  ...                N/A                N/A       N/A
# 1145                 N/A  ...                N/A                N/A       N/A
#
#      mobile_cong_sac          mobile_cam_bien_van_tay  \
# 0         USB Type-C                              N/A
# 1                N/A                              N/A
# 2         USB Type-C  Cảm biến vân tay trong màn hình
# 3         USB Type-C                              N/A
# 4         USB Type-C                              N/A
# ...              ...                              ...
# 1141      USB Type-C                              N/A
# 1142             N/A                              N/A
# 1143      USB Type-C        Cảm biến vân tay cạnh bên
# 1144             N/A                              N/A
# 1145             N/A                              N/A
#
#                                    warranty_information total_count  \
# 0     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...         N/A
# 1     Bảo hành 24 tháng tại trung tâm bảo hành Chính...         N/A
# 2     Bảo hành 12 tháng tại trung tâm bảo hành Chính...          22
# 3     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...           3
# 4     1 ĐỔI 1 trong 30 ngày nếu có lỗi phần cứng nhà...          13
# ...                                                 ...         ...
# 1141  Bảo hành chính hãng 12 tháng tại trung tâm bảo...         N/A
# 1142  Bảo hành 12 tháng tại trung tâm bảo hành Chính...         N/A
# 1143  Bảo hành 12 tháng tại trung tâm bảo hành Chính...         N/A
# 1144  Bảo hành 12 tháng tại trung tâm bảo hành Chính...         N/A
# 1145  Bảo hành 12 tháng tại CellphoneS không loại tr...           2
#
#      average_rating                                 key_selling_points  \
# 0               N/A  iPhone 16 được trang bị vi xử lý Apple A18, ch...
# 1               N/A  Hiệu năng mạnh mẽ với chip MediaTek Dimensity ...
# 2               4.8  Trải nghiệm đỉnh cao với hiệu năng mạnh mẽ từ ...
# 3               5.0  Màn hình Super Retina XDR 6,3 inch lớn hơn có ...
# 4               4.9  Màn hình Super Retina XDR 6,9 inch lớn hơn có ...
# ...             ...                                                ...
# 1141            N/A  Hệ thống camera đỉnh cao cho phép chụp ảnh chi...
# 1142            N/A                                                N/A
# 1143            N/A  Trải nghiệm hình ảnh rộng rãi và thoải mái với...
# 1144            N/A                                                N/A
# 1145            5.0                                                N/A
#
#                                   promotion_information
# 0         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 1     Tặng bộ sạc nhanh Xiaomi 67W (Không áp dụng cù...
# 2     Trả góp 0% đến 12 tháng, 0đ trả trước qua Sams...
# 3         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# 4         Giảm đến 2 triệu qua thẻ tín dụng, ví điện tử
# ...                                                 ...
# 1141                                                N/A
# 1142                                                N/A
# 1143                                                N/A
# 1144                                                N/A
# 1145                                                N/A
#
# [1146 rows x 27 columns]

# %%
df.to_csv('processed_data.csv', index=False, encoding='utf-8-sig')

# %%
camera_back_df = df[['product_id', 'camera_back']].copy()
camera_back_df.to_csv('camera_back.csv', index=False, encoding='utf-8-sig')

# %%
camera_front_df = df[['product_id', 'camera_front']].copy()
camera_front_df.to_csv('camera_front.csv', index=False, encoding='utf-8-sig')

# %%
camera_video_df = df[['product_id', 'camera_video']].copy()
camera_video_df.to_csv('camera_video.csv', index=False, encoding='utf-8-sig')
